# %%
import torch
import pickle
#import matplotlib as plt
from tdnn import *
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch.optim as optim
from torch.utils.data import DataLoader
import os
import time
import sys
from libplda import *
from torch_plda import *
from utils import *
print(sys.executable)
# Out:
# /Users/tanikin/anaconda3/bin/python

# %%
with open('test1.pkl','rb') as f:
    X,y = pickle.load(f)

    
y = torch.tensor(y,dtype = torch.float32)    
y_ = torch.argmax(y,dim=1)
K = torch.unique(y_, sorted = True)
x = torch.tensor(X,dtype = torch.float32)
# trainloader = DataLoader(list(zip(X,y)), shuffle=False, batch_size=15)
# x = torch.mean(x,dim=1)

# %%
x.shape,y.shape
x=torch.mean(x,dim=1)
# for i in K:
#     count =0
#     for j in y_:
#         if j==i:
#             count+=1
#     print(count)
#     print('==============')
    
# # # K.shape
# y
x.shape
# Out:
# torch.Size([1680, 24])

# %%
L =PLDA()

# N,d = x.size(0),x.size(2)
# m = torch.mean(x,dim=0)
# m =torch.mean(m,dim=0)
# S_w, S_b = torch.zeros(d, d), torch.zeros(d, d)
# # for k in K:
# # k = K[0]
# for k in K:
#     C_k = select_class(x,y_,k)
#     C_k = torch.mean(C_k,dim=1)
#     n_k = C_k.size(0)
#     m_k= torch.mean(C_k,dim=0)

#     diff_X_k = C_k - m_k#.expand(C_k.size(0), -1)

#     diff_mk_m = m_k - m
#     S_w_k = torch.matmul(diff_X_k.permute(1, 0), diff_X_k)#with-in class variation
#     S_b_k = n_k * torch.matmul(diff_mk_m.unsqueeze(1), diff_mk_m.unsqueeze(0)) #between class variation
#     S_w += S_w_k
#     S_b += S_b_k

# S_b /=N
# S_w /=N

# %%
# diff_X_k.shape
# diff_mk_m.unsqueeze(1).shape
# S_w
L.fit(x,y_)
# L.m
we=PLDA(x,y_)

# %%
# _, W = eigh(S_b,S_w)
# # W
# W = torch.tensor(W)
we

# %%
# WT = W.transpose(0,1)
# #WT

# Lambda_b = torch.matmul(torch.matmul(WT, S_b), W).diagonal().diag()
# Lambda_w = torch.matmul(torch.matmul(WT, S_w), W).diagonal().diag()

# %%
# C_k.shape

# n = N / torch.unique(y_).size(0)

# nfactorA = n / (n - 1)
# A = torch.inverse(WT) * ((nfactorA * Lambda_w) ** .5)
# nfactorPsi = (n - 1) / n
# Psi = torch.clamp(nfactorPsi * (Lambda_b / Lambda_w) - 1 / n, min=0)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-259-2e5651a7ef13> in <module>
# ----> 1 nfactorA.shape
#
# AttributeError: 'float' object has no attribute 'shape'

# %%
m.unsqueeze(1), A.inverse(), Psi.diagonal()
# Out:
# (tensor([[ 3.0591e-08],
#          [-1.1945e-08],
#          [-2.0765e-08],
#          [-3.9027e-09],
#          [ 1.8957e-08],
#          [ 2.1928e-08],
#          [ 3.6095e-09],
#          [ 6.9430e-09],
#          [-1.1506e-09],
#          [ 5.0250e-09],
#          [-1.0631e-09],
#          [ 9.3157e-09],
#          [-3.1906e-09],
#          [ 4.4965e-11],
#          [-1.1701e-08],
#          [-1.7986e-09],
#          [-1.5719e-09],
#          [ 3.9606e-10],
#          [ 1.0838e-08],
#          [-1.1467e-08],
#          [ 3.8997e-08],
#          [ 1.3719e-08],
#          [ 5.6885e-08],
#          [ 9.4059e-08]]),
#  tensor([[ 1.4570e+08,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00, -0.0000e+00],
# ...
